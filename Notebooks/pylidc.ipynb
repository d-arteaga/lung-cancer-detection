# %% [markdown]
# # pylidc library
#
# This file explores the *pylidc* library, a Python library designed specficially for the LIDC-IDRI dataset

# %%
import pylidc as pl
import numpy as np

# Query the first 20 patients
patients = pl.query(pl.Scan).limit(20).all()

for i, scan in enumerate(patients):
    print(f"\nPatient {i+1} (Scan ID: {scan.id})")
    
    # Get all annotations for this scan
    anns = scan.annotations
    
    if len(anns) == 0:
        print("  No nodules annotated for this patient")
        continue
    
    # Print malignancy for each nodule
    for j, ann in enumerate(anns):
        print(f"  Nodule {j+1}:")
        print(f"    Malignancy rating: {ann.malignancy}")
        # print(f"    Malignancy meaning: {ann.malignancy_description}")
        print(f"    Nodule ID: {ann.id}")
        # print(f"    Consensus nodule? {ann.consensus}")
        
        # If you want to see all 4 radiologists' ratings:
        # print("    All radiologists' malignancy ratings:")
        # # for k, val in enumerate(ann.malignancy_vals):
        # #     print(f"      Radiologist {k+1}: {val}")
# Out:
# Patient 1 (Scan ID: 1)
#   Nodule 1:
#     Malignancy rating: 3
#     Nodule ID: 1
#   Nodule 2:
#     Malignancy rating: 3
#     Nodule ID: 2
#   Nodule 3:
#     Malignancy rating: 4
#     Nodule ID: 3
#   Nodule 4:
#     Malignancy rating: 5
#     Nodule ID: 4
#   Nodule 5:
#     Malignancy rating: 4
#     Nodule ID: 5
#   Nodule 6:
#     Malignancy rating: 4
#     Nodule ID: 6
#   Nodule 7:
#     Malignancy rating: 5
#     Nodule ID: 7
#   Nodule 8:
#     Malignancy rating: 1
#     Nodule ID: 8
#   Nodule 9:
#     Malignancy rating: 5
#     Nodule ID: 9
#   Nodule 10:
#     Malignancy rating: 5
#     Nodule ID: 10
#   Nodule 11:
#     Malignancy rating: 3
#     Nodule ID: 11
#   Nodule 12:
#     Malignancy rating: 3
#     Nodule ID: 12
#   Nodule 13:
#     Malignancy rating: 3
#     Nodule ID: 13
#
# Patient 2 (Scan ID: 2)
#   Nodule 1:
#     Malignancy rating: 5
#     Nodule ID: 14
#   Nodule 2:
#     Malignancy rating: 2
#     Nodule ID: 15
#   Nodule 3:
#     Malignancy rating: 5
#     Nodule ID: 16
#   Nodule 4:
#     Malignancy rating: 3
#     Nodule ID: 17
#   Nodule 5:
#     Malignancy rating: 2
#     Nodule ID: 18
#   Nodule 6:
#     Malignancy rating: 4
#     Nodule ID: 19
#   Nodule 7:
#     Malignancy rating: 3
#     Nodule ID: 20
#   Nodule 8:
#     Malignancy rating: 2
#     Nodule ID: 21
#   Nodule 9:
#     Malignancy rating: 3
#     Nodule ID: 22
#
# Patient 3 (Scan ID: 3)
#   Nodule 1:
#     Malignancy rating: 3
#     Nodule ID: 23
#   Nodule 2:
#     Malignancy rating: 3
#     Nodule ID: 24
#   Nodule 3:
#     Malignancy rating: 1
#     Nodule ID: 25
#   Nodule 4:
#     Malignancy rating: 3
#     Nodule ID: 26
#
# Patient 4 (Scan ID: 4)
#   Nodule 1:
#     Malignancy rating: 1
#     Nodule ID: 27
#   Nodule 2:
#     Malignancy rating: 3
#     Nodule ID: 28
#
# Patient 5 (Scan ID: 5)
#   Nodule 1:
#     Malignancy rating: 2
#     Nodule ID: 29
#   Nodule 2:
#     Malignancy rating: 3
#     Nodule ID: 30
#   Nodule 3:
#     Malignancy rating: 3
#     Nodule ID: 31
#   Nodule 4:
#     Malignancy rating: 4
#     Nodule ID: 32
#   Nodule 5:
#     Malignancy rating: 3
#     Nodule ID: 33
#   Nodule 6:
#     Malignancy rating: 3
#     Nodule ID: 34
#
# Patient 6 (Scan ID: 6)
#   Nodule 1:
#     Malignancy rating: 3
#     Nodule ID: 35
#   Nodule 2:
#     Malignancy rating: 5
#     Nodule ID: 36
#   Nodule 3:
#     Malignancy rating: 3
#     Nodule ID: 37
#   Nodule 4:
#     Malignancy rating: 3
#     Nodule ID: 38
#
# Patient 7 (Scan ID: 7)
#   Nodule 1:
#     Malignancy rating: 4
#     Nodule ID: 39
#   Nodule 2:
#     Malignancy rating: 2
#     Nodule ID: 40
#   Nodule 3:
#     Malignancy rating: 1
#     Nodule ID: 41
#   Nodule 4:
#     Malignancy rating: 1
#     Nodule ID: 42
#   Nodule 5:
#     Malignancy rating: 3
#     Nodule ID: 43
#   Nodule 6:
#     Malignancy rating: 4
#     Nodule ID: 44
#   Nodule 7:
#     Malignancy rating: 5
#     Nodule ID: 45
#   Nodule 8:
#     Malignancy rating: 3
#     Nodule ID: 46
#   Nodule 9:
#     Malignancy rating: 3
#     Nodule ID: 47
#   Nodule 10:
#     Malignancy rating: 3
#     Nodule ID: 48
#   Nodule 11:
#     Malignancy rating: 3
#     Nodule ID: 49
#   Nodule 12:
#     Malignancy rating: 3
#     Nodule ID: 50
#
# Patient 8 (Scan ID: 8)
#   Nodule 1:
#     Malignancy rating: 1
#     Nodule ID: 51
#   Nodule 2:
#     Malignancy rating: 2
#     Nodule ID: 52
#   Nodule 3:
#     Malignancy rating: 1
#     Nodule ID: 53
#   Nodule 4:
#     Malignancy rating: 2
#     Nodule ID: 54
#   Nodule 5:
#     Malignancy rating: 1
#     Nodule ID: 55
#   Nodule 6:
#     Malignancy rating: 1
#     Nodule ID: 56
#   Nodule 7:
#     Malignancy rating: 1
#     Nodule ID: 57
#   Nodule 8:
#     Malignancy rating: 1
#     Nodule ID: 58
#   Nodule 9:
#     Malignancy rating: 1
#     Nodule ID: 59
#   Nodule 10:
#     Malignancy rating: 3
#     Nodule ID: 60
#   Nodule 11:
#     Malignancy rating: 3
#     Nodule ID: 61
#   Nodule 12:
#     Malignancy rating: 3
#     Nodule ID: 62
#   Nodule 13:
#     Malignancy rating: 3
#     Nodule ID: 63
#   Nodule 14:
#     Malignancy rating: 3
#     Nodule ID: 64
#   Nodule 15:
#     Malignancy rating: 3
#     Nodule ID: 65
#   Nodule 16:
#     Malignancy rating: 4
#     Nodule ID: 66
#   Nodule 17:
#     Malignancy rating: 3
#     Nodule ID: 67
#   Nodule 18:
#     Malignancy rating: 2
#     Nodule ID: 68
#   Nodule 19:
#     Malignancy rating: 2
#     Nodule ID: 69
#   Nodule 20:
#     Malignancy rating: 3
#     Nodule ID: 70
#   Nodule 21:
#     Malignancy rating: 3
#     Nodule ID: 71
#
# Patient 9 (Scan ID: 9)
#   Nodule 1:
#     Malignancy rating: 1
#     Nodule ID: 72
#   Nodule 2:
#     Malignancy rating: 1
#     Nodule ID: 73
#   Nodule 3:
#     Malignancy rating: 3
#     Nodule ID: 74
#   Nodule 4:
#     Malignancy rating: 4
#     Nodule ID: 75
#
# Patient 10 (Scan ID: 10)
#   Nodule 1:
#     Malignancy rating: 2
#     Nodule ID: 76
#   Nodule 2:
#     Malignancy rating: 4
#     Nodule ID: 77
#   Nodule 3:
#     Malignancy rating: 5
#     Nodule ID: 78
#
# Patient 11 (Scan ID: 11)
#   Nodule 1:
#     Malignancy rating: 2
#     Nodule ID: 79
#   Nodule 2:
#     Malignancy rating: 5
#     Nodule ID: 80
#   Nodule 3:
#     Malignancy rating: 3
#     Nodule ID: 81
#   Nodule 4:
#     Malignancy rating: 3
#     Nodule ID: 82
#   Nodule 5:
#     Malignancy rating: 5
#     Nodule ID: 83
#
# Patient 12 (Scan ID: 12)
#   Nodule 1:
#     Malignancy rating: 5
#     Nodule ID: 84
#   Nodule 2:
#     Malignancy rating: 5
#     Nodule ID: 85
#   Nodule 3:
#     Malignancy rating: 5
#     Nodule ID: 86
#   Nodule 4:
#     Malignancy rating: 4
#     Nodule ID: 87
#
# Patient 13 (Scan ID: 13)
#   Nodule 1:
#     Malignancy rating: 5
#     Nodule ID: 88
#   Nodule 2:
#     Malignancy rating: 4
#     Nodule ID: 89
#
# Patient 14 (Scan ID: 14)
#   Nodule 1:
#     Malignancy rating: 5
#     Nodule ID: 90
#   Nodule 2:
#     Malignancy rating: 4
#     Nodule ID: 91
#   Nodule 3:
#     Malignancy rating: 4
#     Nodule ID: 92
#   Nodule 4:
#     Malignancy rating: 5
#     Nodule ID: 93
#   Nodule 5:
#     Malignancy rating: 5
#     Nodule ID: 94
#   Nodule 6:
#     Malignancy rating: 4
#     Nodule ID: 95
#   Nodule 7:
#     Malignancy rating: 3
#     Nodule ID: 96
#   Nodule 8:
#     Malignancy rating: 3
#     Nodule ID: 97
#   Nodule 9:
#     Malignancy rating: 3
#     Nodule ID: 98
#   Nodule 10:
#     Malignancy rating: 4
#     Nodule ID: 99
#   Nodule 11:
#     Malignancy rating: 2
#     Nodule ID: 100
#   Nodule 12:
#     Malignancy rating: 2
#     Nodule ID: 101
#   Nodule 13:
#     Malignancy rating: 2
#     Nodule ID: 102
#
# Patient 15 (Scan ID: 15)
#   Nodule 1:
#     Malignancy rating: 2
#     Nodule ID: 103
#   Nodule 2:
#     Malignancy rating: 1
#     Nodule ID: 104
#   Nodule 3:
#     Malignancy rating: 1
#     Nodule ID: 105
#   Nodule 4:
#     Malignancy rating: 1
#     Nodule ID: 106
#
# Patient 16 (Scan ID: 16)
#   Nodule 1:
#     Malignancy rating: 3
#     Nodule ID: 107
#   Nodule 2:
#     Malignancy rating: 3
#     Nodule ID: 108
#   Nodule 3:
#     Malignancy rating: 2
#     Nodule ID: 109
#   Nodule 4:
#     Malignancy rating: 3
#     Nodule ID: 110
#   Nodule 5:
#     Malignancy rating: 3
#     Nodule ID: 111
#   Nodule 6:
#     Malignancy rating: 3
#     Nodule ID: 112
#   Nodule 7:
#     Malignancy rating: 3
#     Nodule ID: 113
#   Nodule 8:
#     Malignancy rating: 2
#     Nodule ID: 114
#   Nodule 9:
#     Malignancy rating: 2
#     Nodule ID: 115
#
# Patient 17 (Scan ID: 17)
#   Nodule 1:
#     Malignancy rating: 2
#     Nodule ID: 116
#   Nodule 2:
#     Malignancy rating: 3
#     Nodule ID: 117
#   Nodule 3:
#     Malignancy rating: 4
#     Nodule ID: 118
#   Nodule 4:
#     Malignancy rating: 3
#     Nodule ID: 119
#   Nodule 5:
#     Malignancy rating: 3
#     Nodule ID: 120
#   Nodule 6:
#     Malignancy rating: 3
#     Nodule ID: 121
#   Nodule 7:
#     Malignancy rating: 2
#     Nodule ID: 122
#   Nodule 8:
#     Malignancy rating: 2
#     Nodule ID: 123
#
# Patient 18 (Scan ID: 18)
#   Nodule 1:
#     Malignancy rating: 5
#     Nodule ID: 124
#   Nodule 2:
#     Malignancy rating: 5
#     Nodule ID: 125
#   Nodule 3:
#     Malignancy rating: 5
#     Nodule ID: 126
#   Nodule 4:
#     Malignancy rating: 5
#     Nodule ID: 127
#   Nodule 5:
#     Malignancy rating: 4
#     Nodule ID: 128
#
# Patient 19 (Scan ID: 19)
#   Nodule 1:
#     Malignancy rating: 3
#     Nodule ID: 129
#   Nodule 2:
#     Malignancy rating: 3
#     Nodule ID: 130
#   Nodule 3:
#     Malignancy rating: 3
#     Nodule ID: 131
#   Nodule 4:
#     Malignancy rating: 3
#     Nodule ID: 132
#   Nodule 5:
#     Malignancy rating: 3
#     Nodule ID: 133
#   Nodule 6:
#     Malignancy rating: 2
#     Nodule ID: 134
#   Nodule 7:
#     Malignancy rating: 2
#     Nodule ID: 135
#
# Patient 20 (Scan ID: 20)
#   Nodule 1:
#     Malignancy rating: 2
#     Nodule ID: 136
#   Nodule 2:
#     Malignancy rating: 2
#     Nodule ID: 137

# %%
import pylidc as pl
import numpy as np

# Patch np.int to avoid AttributeError
if not hasattr(np, 'int'):
    np.int = int

# Query the first 20 patients
patients = pl.query(pl.Scan).limit(20).all()

# Process each patient
for i, scan in enumerate(patients):
    print(f"\nProcessing Patient {i+1} (Scan ID: {scan.id})")
    
    # Get all annotations for this scan
    anns = scan.annotations
    
    if len(anns) == 0:
        print("  No nodules annotated for this patient")
        continue
    
    # Dictionary to track planar views for each nodule
    nodule_views = {"axial": set(), "coronal": set(), "sagittal": set()}
    
    # Process each nodule
    for j, ann in enumerate(anns):
        print(f"  Nodule {j+1}:")
        print(f"    Malignancy rating: {ann.malignancy}")
        
        # Get all slices where this nodule appears
        slice_numbers = set()
        for contour in ann.contours:
            slice_numbers.add(contour.image_k_position)
        
        slice_numbers = sorted(slice_numbers)
        print(f"    Appears on {len(slice_numbers)} axial slices: {slice_numbers}")
        
        # Add to axial view
        nodule_views["axial"].update(slice_numbers)
        
        # Add to coronal and sagittal views
        # Coronal: Y-axis (slice along the height of the body)
        # Sagittal: X-axis (slice along the width of the body)
        for contour in ann.contours:
            for point in contour.to_matrix():
                nodule_views["coronal"].add(point[1])  # Y-axis
                nodule_views["sagittal"].add(point[0])  # X-axis
    
    # Print planar views for this patient
    print(f"  Planar Views for Patient {i+1}:")
    print(f"    Axial slices: {sorted(nodule_views['axial'])}")
    print(f"    Coronal slices: {sorted(nodule_views['coronal'])}")
    print(f"    Sagittal slices: {sorted(nodule_views['sagittal'])}")
# Out:
# Processing Patient 1 (Scan ID: 1)
#   Nodule 1:
#     Malignancy rating: 3
#     Appears on 6 axial slices: [44, 45, 46, 47, 48, 49]
#   Nodule 2:
#     Malignancy rating: 3
#     Appears on 6 axial slices: [23, 24, 25, 26, 27, 28]
#   Nodule 3:
#     Malignancy rating: 4
#     Appears on 8 axial slices: [64, 65, 66, 67, 68, 69, 70, 71]
#   Nodule 4:
#     Malignancy rating: 5
#     Appears on 8 axial slices: [64, 65, 66, 67, 68, 69, 70, 71]
#   Nodule 5:
#     Malignancy rating: 4
#     Appears on 6 axial slices: [44, 45, 46, 47, 48, 49]
#   Nodule 6:
#     Malignancy rating: 4
#     Appears on 6 axial slices: [23, 24, 25, 26, 27, 28]
#   Nodule 7:
#     Malignancy rating: 5
#     Appears on 7 axial slices: [65, 66, 67, 68, 69, 70, 71]
#   Nodule 8:
#     Malignancy rating: 1
#     Appears on 2 axial slices: [47, 48]
#   Nodule 9:
#     Malignancy rating: 5
#     Appears on 4 axial slices: [45, 46, 47, 48]
#   Nodule 10:
#     Malignancy rating: 5
#     Appears on 5 axial slices: [23, 24, 25, 26, 27]
#   Nodule 11:
#     Malignancy rating: 3
#     Appears on 8 axial slices: [64, 65, 66, 67, 68, 69, 70, 71]
#   Nodule 12:
#     Malignancy rating: 3
#     Appears on 6 axial slices: [44, 45, 46, 47, 48, 49]
#   Nodule 13:
#     Malignancy rating: 3
#     Appears on 4 axial slices: [24, 25, 26, 27]
#   Planar Views for Patient 1:
#     Axial slices: [23, 24, 25, 26, 27, 28, 44, 45, 46, 47, 48, 49, 64, 65, 66, 67, 68, 69, 70, 71]
#     Coronal slices: [306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375]
#     Sagittal slices: [146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 345, 346, 347, 348, 349, 350, 351, 352]
#
# Processing Patient 2 (Scan ID: 2)
#   Nodule 1:
#     Malignancy rating: 5
#     Appears on 7 axial slices: [80, 81, 82, 83, 84, 85, 86]
#   Nodule 2:
#     Malignancy rating: 2
#     Appears on 1 axial slices: [52]
#   Nodule 3:
#     Malignancy rating: 5
#     Appears on 8 axial slices: [36, 37, 38, 39, 40, 41, 42, 43]
#   Nodule 4:
#     Malignancy rating: 3
#     Appears on 7 axial slices: [80, 81, 82, 83, 84, 85, 86]
#   Nodule 5:
#     Malignancy rating: 2
#     Appears on 5 axial slices: [37, 38, 39, 40, 41]
#   Nodule 6:
#     Malignancy rating: 4
#     Appears on 11 axial slices: [79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
#   Nodule 7:
#     Malignancy rating: 3
#     Appears on 9 axial slices: [36, 37, 38, 39, 40, 41, 42, 43, 44]
#   Nodule 8:
#     Malignancy rating: 2
#     Appears on 7 axial slices: [80, 81, 82, 83, 84, 85, 86]
#   Nodule 9:
#     Malignancy rating: 3
#     Appears on 6 axial slices: [38, 39, 40, 41, 42, 43]
#   Planar Views for Patient 2:
#     Axial slices: [36, 37, 38, 39, 40, 41, 42, 43, 44, 52, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
#     Coronal slices: [96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 223, 224, 225, 226, 227, 228, 229]
#     Sagittal slices: [337, 338, 339, 340, 341, 342, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387]
#
# Processing Patient 3 (Scan ID: 3)
#   Nodule 1:
#     Malignancy rating: 3
#     Appears on 5 axial slices: [67, 68, 69, 70, 71]
#   Nodule 2:
#     Malignancy rating: 3
#     Appears on 5 axial slices: [67, 68, 69, 70, 71]
#   Nodule 3:
#     Malignancy rating: 1
#     Appears on 3 axial slices: [68, 69, 70]
#   Nodule 4:
#     Malignancy rating: 3
#     Appears on 5 axial slices: [67, 68, 69, 70, 71]
#   Planar Views for Patient 3:
#     Axial slices: [67, 68, 69, 70, 71]
#     Coronal slices: [350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371]
#     Sagittal slices: [372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398]
#
# Processing Patient 4 (Scan ID: 4)
#   Nodule 1:
#     Malignancy rating: 1
#     Appears on 2 axial slices: [69, 70]
#   Nodule 2:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [69, 70]
#   Planar Views for Patient 4:
#     Axial slices: [69, 70]
#     Coronal slices: [45, 46, 47, 48, 49, 50, 51, 52]
#     Sagittal slices: [301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321]
#
# Processing Patient 5 (Scan ID: 5)
#   Nodule 1:
#     Malignancy rating: 2
#     Appears on 2 axial slices: [48, 49]
#   Nodule 2:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [45, 46]
#   Nodule 3:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [48, 49]
#   Nodule 4:
#     Malignancy rating: 4
#     Appears on 2 axial slices: [45, 46]
#   Nodule 5:
#     Malignancy rating: 3
#     Appears on 3 axial slices: [47, 48, 49]
#   Nodule 6:
#     Malignancy rating: 3
#     Appears on 4 axial slices: [44, 45, 46, 47]
#   Planar Views for Patient 5:
#     Axial slices: [44, 45, 46, 47, 48, 49]
#     Coronal slices: [89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205]
#     Sagittal slices: [360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385]
#
# Processing Patient 6 (Scan ID: 6)
#   Nodule 1:
#     Malignancy rating: 3
#     Appears on 8 axial slices: [88, 89, 90, 91, 92, 93, 94, 95]
#   Nodule 2:
#     Malignancy rating: 5
#     Appears on 8 axial slices: [88, 89, 90, 91, 92, 93, 94, 95]
#   Nodule 3:
#     Malignancy rating: 3
#     Appears on 8 axial slices: [88, 89, 90, 91, 92, 93, 94, 95]
#   Nodule 4:
#     Malignancy rating: 3
#     Appears on 8 axial slices: [88, 89, 90, 91, 92, 93, 94, 95]
#   Planar Views for Patient 6:
#     Axial slices: [88, 89, 90, 91, 92, 93, 94, 95]
#     Coronal slices: [123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152]
#     Sagittal slices: [272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302]
#
# Processing Patient 7 (Scan ID: 7)
#   Nodule 1:
#     Malignancy rating: 4
#     Appears on 6 axial slices: [95, 96, 97, 98, 99, 100]
#   Nodule 2:
#     Malignancy rating: 2
#     Appears on 6 axial slices: [95, 96, 97, 98, 99, 100]
#   Nodule 3:
#     Malignancy rating: 1
#     Appears on 3 axial slices: [91, 92, 93]
#   Nodule 4:
#     Malignancy rating: 1
#     Appears on 3 axial slices: [72, 73, 74]
#   Nodule 5:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [111, 112]
#   Nodule 6:
#     Malignancy rating: 4
#     Appears on 1 axial slices: [110]
#   Nodule 7:
#     Malignancy rating: 5
#     Appears on 5 axial slices: [96, 97, 98, 99, 100]
#   Nodule 8:
#     Malignancy rating: 3
#     Appears on 1 axial slices: [93]
#   Nodule 9:
#     Malignancy rating: 3
#     Appears on 3 axial slices: [91, 92, 93]
#   Nodule 10:
#     Malignancy rating: 3
#     Appears on 3 axial slices: [72, 73, 74]
#   Nodule 11:
#     Malignancy rating: 3
#     Appears on 5 axial slices: [96, 97, 98, 99, 100]
#   Nodule 12:
#     Malignancy rating: 3
#     Appears on 3 axial slices: [72, 73, 74]
#   Planar Views for Patient 7:
#     Axial slices: [72, 73, 74, 91, 92, 93, 95, 96, 97, 98, 99, 100, 110, 111, 112]
#     Coronal slices: [121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444]
#     Sagittal slices: [326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420]
#
# Processing Patient 8 (Scan ID: 8)
#   Nodule 1:
#     Malignancy rating: 1
#     Appears on 2 axial slices: [136, 137]
#   Nodule 2:
#     Malignancy rating: 2
#     Appears on 6 axial slices: [122, 123, 124, 125, 126, 127]
#   Nodule 3:
#     Malignancy rating: 1
#     Appears on 2 axial slices: [123, 124]
#   Nodule 4:
#     Malignancy rating: 2
#     Appears on 1 axial slices: [76]
#   Nodule 5:
#     Malignancy rating: 1
#     Appears on 2 axial slices: [80, 81]
#   Nodule 6:
#     Malignancy rating: 1
#     Appears on 2 axial slices: [88, 89]
#   Nodule 7:
#     Malignancy rating: 1
#     Appears on 3 axial slices: [99, 100, 101]
#   Nodule 8:
#     Malignancy rating: 1
#     Appears on 2 axial slices: [125, 126]
#   Nodule 9:
#     Malignancy rating: 1
#     Appears on 2 axial slices: [136, 137]
#   Nodule 10:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [125, 126]
#   Nodule 11:
#     Malignancy rating: 3
#     Appears on 6 axial slices: [122, 123, 124, 125, 126, 127]
#   Nodule 12:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [123, 124]
#   Nodule 13:
#     Malignancy rating: 3
#     Appears on 3 axial slices: [112, 113, 114]
#   Nodule 14:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [99, 100]
#   Nodule 15:
#     Malignancy rating: 3
#     Appears on 1 axial slices: [88]
#   Nodule 16:
#     Malignancy rating: 4
#     Appears on 1 axial slices: [80]
#   Nodule 17:
#     Malignancy rating: 3
#     Appears on 1 axial slices: [76]
#   Nodule 18:
#     Malignancy rating: 2
#     Appears on 5 axial slices: [123, 124, 125, 126, 127]
#   Nodule 19:
#     Malignancy rating: 2
#     Appears on 3 axial slices: [122, 123, 124]
#   Nodule 20:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [80, 81]
#   Nodule 21:
#     Malignancy rating: 3
#     Appears on 1 axial slices: [76]
#   Planar Views for Patient 8:
#     Axial slices: [76, 80, 81, 88, 89, 99, 100, 101, 112, 113, 114, 122, 123, 124, 125, 126, 127, 136, 137]
#     Coronal slices: [163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 193, 194, 195, 196, 197, 198, 199, 200, 303, 304, 305, 306, 307, 308, 309, 310, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 412, 413, 414, 415, 416, 417, 418]
#     Sagittal slices: [181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354]
#
# Processing Patient 9 (Scan ID: 9)
#   Nodule 1:
#     Malignancy rating: 1
#     Appears on 4 axial slices: [88, 89, 90, 91]
#   Nodule 2:
#     Malignancy rating: 1
#     Appears on 3 axial slices: [63, 64, 65]
#   Nodule 3:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [63, 64]
#   Nodule 4:
#     Malignancy rating: 4
#     Appears on 4 axial slices: [88, 89, 90, 91]
#   Planar Views for Patient 9:
#     Axial slices: [63, 64, 65, 88, 89, 90, 91]
#     Coronal slices: [139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 177, 178, 179, 180, 181, 182, 183, 184, 185]
#     Sagittal slices: [203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316]
#
# Processing Patient 10 (Scan ID: 10)
#   Nodule 1:
#     Malignancy rating: 2
#     Appears on 3 axial slices: [73, 74, 75]
#   Nodule 2:
#     Malignancy rating: 4
#     Appears on 3 axial slices: [73, 74, 75]
#   Nodule 3:
#     Malignancy rating: 5
#     Appears on 3 axial slices: [73, 74, 75]
#   Planar Views for Patient 10:
#     Axial slices: [73, 74, 75]
#     Coronal slices: [406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426]
#     Sagittal slices: [308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324]
#
# Processing Patient 11 (Scan ID: 11)
#   Nodule 1:
#     Malignancy rating: 2
#     Appears on 8 axial slices: [41, 42, 43, 44, 45, 46, 47, 48]
#   Nodule 2:
#     Malignancy rating: 5
#     Appears on 7 axial slices: [41, 42, 43, 44, 45, 46, 47]
#   Nodule 3:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [36, 37]
#   Nodule 4:
#     Malignancy rating: 3
#     Appears on 8 axial slices: [41, 42, 43, 44, 45, 46, 47, 48]
#   Nodule 5:
#     Malignancy rating: 5
#     Appears on 9 axial slices: [40, 41, 42, 43, 44, 45, 46, 47, 48]
#   Planar Views for Patient 11:
#     Axial slices: [36, 37, 40, 41, 42, 43, 44, 45, 46, 47, 48]
#     Coronal slices: [200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473, 474, 475]
#     Sagittal slices: [246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296]
#
# Processing Patient 12 (Scan ID: 12)
#   Nodule 1:
#     Malignancy rating: 5
#     Appears on 8 axial slices: [86, 87, 88, 89, 90, 91, 92, 93]
#   Nodule 2:
#     Malignancy rating: 5
#     Appears on 7 axial slices: [87, 88, 89, 90, 91, 92, 93]
#   Nodule 3:
#     Malignancy rating: 5
#     Appears on 8 axial slices: [86, 87, 88, 89, 90, 91, 92, 93]
#   Nodule 4:
#     Malignancy rating: 4
#     Appears on 9 axial slices: [86, 87, 88, 89, 90, 91, 92, 93, 94]
#   Planar Views for Patient 12:
#     Axial slices: [86, 87, 88, 89, 90, 91, 92, 93, 94]
#     Coronal slices: [297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340]
#     Sagittal slices: [340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391]
#
# Processing Patient 13 (Scan ID: 13)
#   Nodule 1:
#     Malignancy rating: 5
#     Appears on 28 axial slices: [171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198]
#   Nodule 2:
#     Malignancy rating: 4
#     Appears on 23 axial slices: [176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198]
#   Planar Views for Patient 13:
#     Axial slices: [171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198]
#     Coronal slices: [324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373]
#     Sagittal slices: [334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378]
#
# Processing Patient 14 (Scan ID: 14)
#   Nodule 1:
#     Malignancy rating: 5
#     Appears on 7 axial slices: [72, 73, 74, 75, 76, 77, 78]
#   Nodule 2:
#     Malignancy rating: 4
#     Appears on 4 axial slices: [81, 82, 83, 84]
#   Nodule 3:
#     Malignancy rating: 4
#     Appears on 5 axial slices: [82, 83, 84, 85, 86]
#   Nodule 4:
#     Malignancy rating: 5
#     Appears on 7 axial slices: [72, 73, 74, 75, 76, 77, 78]
#   Nodule 5:
#     Malignancy rating: 5
#     Appears on 5 axial slices: [82, 83, 84, 85, 86]
#   Nodule 6:
#     Malignancy rating: 4
#     Appears on 2 axial slices: [82, 83]
#   Nodule 7:
#     Malignancy rating: 3
#     Appears on 5 axial slices: [82, 83, 84, 85, 86]
#   Nodule 8:
#     Malignancy rating: 3
#     Appears on 4 axial slices: [81, 82, 83, 84]
#   Nodule 9:
#     Malignancy rating: 3
#     Appears on 7 axial slices: [72, 73, 74, 75, 76, 77, 78]
#   Nodule 10:
#     Malignancy rating: 4
#     Appears on 10 axial slices: [70, 71, 72, 73, 74, 75, 76, 77, 78, 79]
#   Nodule 11:
#     Malignancy rating: 2
#     Appears on 4 axial slices: [81, 82, 83, 84]
#   Nodule 12:
#     Malignancy rating: 2
#     Appears on 8 axial slices: [81, 82, 83, 84, 85, 86, 87, 88]
#   Nodule 13:
#     Malignancy rating: 2
#     Appears on 8 axial slices: [62, 63, 64, 65, 66, 67, 68, 69]
#   Planar Views for Patient 14:
#     Axial slices: [62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 81, 82, 83, 84, 85, 86, 87, 88]
#     Coronal slices: [212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388]
#     Sagittal slices: [192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372]
#
# Processing Patient 15 (Scan ID: 15)
#   Nodule 1:
#     Malignancy rating: 2
#     Appears on 4 axial slices: [74, 75, 76, 77]
#   Nodule 2:
#     Malignancy rating: 1
#     Appears on 3 axial slices: [75, 76, 77]
#   Nodule 3:
#     Malignancy rating: 1
#     Appears on 4 axial slices: [74, 75, 76, 77]
#   Nodule 4:
#     Malignancy rating: 1
#     Appears on 5 axial slices: [74, 75, 76, 77, 78]
#   Planar Views for Patient 15:
#     Axial slices: [74, 75, 76, 77, 78]
#     Coronal slices: [136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146]
#     Sagittal slices: [318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328]
#
# Processing Patient 16 (Scan ID: 16)
#   Nodule 1:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [77, 78]
#   Nodule 2:
#     Malignancy rating: 3
#     Appears on 3 axial slices: [79, 80, 81]
#   Nodule 3:
#     Malignancy rating: 2
#     Appears on 2 axial slices: [87, 88]
#   Nodule 4:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [77, 78]
#   Nodule 5:
#     Malignancy rating: 3
#     Appears on 1 axial slices: [80]
#   Nodule 6:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [80, 81]
#   Nodule 7:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [77, 78]
#   Nodule 8:
#     Malignancy rating: 2
#     Appears on 2 axial slices: [77, 78]
#   Nodule 9:
#     Malignancy rating: 2
#     Appears on 3 axial slices: [79, 80, 81]
#   Planar Views for Patient 16:
#     Axial slices: [77, 78, 79, 80, 81, 87, 88]
#     Coronal slices: [122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412]
#     Sagittal slices: [373, 374, 375, 376, 377, 378, 379, 380, 381, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414]
#
# Processing Patient 17 (Scan ID: 17)
#   Nodule 1:
#     Malignancy rating: 2
#     Appears on 2 axial slices: [54, 55]
#   Nodule 2:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [83, 84]
#   Nodule 3:
#     Malignancy rating: 4
#     Appears on 2 axial slices: [83, 84]
#   Nodule 4:
#     Malignancy rating: 3
#     Appears on 1 axial slices: [68]
#   Nodule 5:
#     Malignancy rating: 3
#     Appears on 3 axial slices: [83, 84, 85]
#   Nodule 6:
#     Malignancy rating: 3
#     Appears on 1 axial slices: [68]
#   Nodule 7:
#     Malignancy rating: 2
#     Appears on 3 axial slices: [83, 84, 85]
#   Nodule 8:
#     Malignancy rating: 2
#     Appears on 4 axial slices: [69, 70, 71, 72]
#   Planar Views for Patient 17:
#     Axial slices: [54, 55, 68, 69, 70, 71, 72, 83, 84, 85]
#     Coronal slices: [186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396]
#     Sagittal slices: [328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364]
#
# Processing Patient 18 (Scan ID: 18)
#   Nodule 1:
#     Malignancy rating: 5
#     Appears on 10 axial slices: [103, 104, 105, 106, 107, 108, 109, 110, 111, 112]
#   Nodule 2:
#     Malignancy rating: 5
#     Appears on 12 axial slices: [118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129]
#   Nodule 3:
#     Malignancy rating: 5
#     Appears on 11 axial slices: [102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112]
#   Nodule 4:
#     Malignancy rating: 5
#     Appears on 11 axial slices: [103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113]
#   Nodule 5:
#     Malignancy rating: 4
#     Appears on 13 axial slices: [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113]
#   Planar Views for Patient 18:
#     Axial slices: [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129]
#     Coronal slices: [173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305]
#     Sagittal slices: [255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315]
#
# Processing Patient 19 (Scan ID: 19)
#   Nodule 1:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [70, 71]
#   Nodule 2:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [88, 89]
#   Nodule 3:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [70, 71]
#   Nodule 4:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [88, 89]
#   Nodule 5:
#     Malignancy rating: 3
#     Appears on 2 axial slices: [88, 89]
#   Nodule 6:
#     Malignancy rating: 2
#     Appears on 2 axial slices: [70, 71]
#   Nodule 7:
#     Malignancy rating: 2
#     Appears on 3 axial slices: [87, 88, 89]
#   Planar Views for Patient 19:
#     Axial slices: [70, 71, 87, 88, 89]
#     Coronal slices: [112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374]
#     Sagittal slices: [265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294]
#
# Processing Patient 20 (Scan ID: 20)
#   Nodule 1:
#     Malignancy rating: 2
#     Appears on 3 axial slices: [102, 103, 104]
#   Nodule 2:
#     Malignancy rating: 2
#     Appears on 4 axial slices: [165, 166, 167, 168]
#   Planar Views for Patient 20:
#     Axial slices: [102, 103, 104, 165, 166, 167, 168]
#     Coronal slices: [198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 300, 301, 302, 303, 304, 305, 306, 307]
#     Sagittal slices: [320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 331, 332, 333, 334, 335, 336, 337, 338, 339]

# %%
import pylidc as pl
import numpy as np

# Patch np.int to avoid AttributeError
if not hasattr(np, 'int'):
    np.int = int

# Query the first 100 patients
patients = pl.query(pl.Scan).limit(100).all()

# List to store patient IDs with benign nodules
benign_patients = []

# Process each patient
for i, scan in enumerate(patients):
    print(f"\nProcessing Patient {i+1} (Scan ID: {scan.id})")
    
    # Get all annotations for this scan
    anns = scan.annotations
    
    if len(anns) == 0:
        print("  No nodules annotated for this patient")
        continue
    
    # Check if any nodule has a malignancy score of 1 or 2
    has_benign_nodule = any(ann.malignancy in [1, 2] for ann in anns)
    
    if has_benign_nodule:
        benign_patients.append(scan.patient_id)
        print(f"  Patient {scan.patient_id} has a benign nodule (malignancy score of 1 or 2).")

# Print the results
print("\nPatients with benign nodules (malignancy score of 1 or 2):")
print(benign_patients)
# Out:
# Processing Patient 1 (Scan ID: 1)
#   Patient LIDC-IDRI-0078 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 2 (Scan ID: 2)
#   Patient LIDC-IDRI-0069 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 3 (Scan ID: 3)
#   Patient LIDC-IDRI-0079 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 4 (Scan ID: 4)
#   Patient LIDC-IDRI-0101 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 5 (Scan ID: 5)
#   Patient LIDC-IDRI-0110 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 6 (Scan ID: 6)
#
# Processing Patient 7 (Scan ID: 7)
#   Patient LIDC-IDRI-0132 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 8 (Scan ID: 8)
#   Patient LIDC-IDRI-0136 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 9 (Scan ID: 9)
#   Patient LIDC-IDRI-0150 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 10 (Scan ID: 10)
#   Patient LIDC-IDRI-0151 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 11 (Scan ID: 11)
#   Patient LIDC-IDRI-0154 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 12 (Scan ID: 12)
#
# Processing Patient 13 (Scan ID: 13)
#
# Processing Patient 14 (Scan ID: 14)
#   Patient LIDC-IDRI-0003 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 15 (Scan ID: 15)
#   Patient LIDC-IDRI-0004 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 16 (Scan ID: 16)
#   Patient LIDC-IDRI-0005 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 17 (Scan ID: 17)
#   Patient LIDC-IDRI-0006 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 18 (Scan ID: 18)
#
# Processing Patient 19 (Scan ID: 19)
#   Patient LIDC-IDRI-0008 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 20 (Scan ID: 20)
#   Patient LIDC-IDRI-0009 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 21 (Scan ID: 21)
#   Patient LIDC-IDRI-0010 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 22 (Scan ID: 22)
#   Patient LIDC-IDRI-0011 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 23 (Scan ID: 23)
#   Patient LIDC-IDRI-0012 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 24 (Scan ID: 24)
#   Patient LIDC-IDRI-0013 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 25 (Scan ID: 25)
#   Patient LIDC-IDRI-0014 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 26 (Scan ID: 26)
#
# Processing Patient 27 (Scan ID: 27)
#   Patient LIDC-IDRI-0016 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 28 (Scan ID: 28)
#   Patient LIDC-IDRI-0017 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 29 (Scan ID: 29)
#   Patient LIDC-IDRI-0018 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 30 (Scan ID: 30)
#   Patient LIDC-IDRI-0019 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 31 (Scan ID: 31)
#   Patient LIDC-IDRI-0020 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 32 (Scan ID: 32)
#   Patient LIDC-IDRI-0021 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 33 (Scan ID: 33)
#   Patient LIDC-IDRI-0022 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 34 (Scan ID: 34)
#
# Processing Patient 35 (Scan ID: 35)
#   Patient LIDC-IDRI-0024 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 36 (Scan ID: 36)
#   Patient LIDC-IDRI-0025 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 37 (Scan ID: 37)
#   Patient LIDC-IDRI-0026 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 38 (Scan ID: 38)
#   Patient LIDC-IDRI-0027 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 39 (Scan ID: 39)
#   No nodules annotated for this patient
#
# Processing Patient 40 (Scan ID: 40)
#
# Processing Patient 41 (Scan ID: 41)
#   Patient LIDC-IDRI-0030 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 42 (Scan ID: 42)
#   Patient LIDC-IDRI-0031 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 43 (Scan ID: 43)
#   No nodules annotated for this patient
#
# Processing Patient 44 (Scan ID: 44)
#   Patient LIDC-IDRI-0033 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 45 (Scan ID: 45)
#   Patient LIDC-IDRI-0034 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 46 (Scan ID: 46)
#
# Processing Patient 47 (Scan ID: 47)
#
# Processing Patient 48 (Scan ID: 48)
#
# Processing Patient 49 (Scan ID: 49)
#
# Processing Patient 50 (Scan ID: 50)
#   Patient LIDC-IDRI-0039 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 51 (Scan ID: 51)
#   Patient LIDC-IDRI-0040 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 52 (Scan ID: 52)
#   Patient LIDC-IDRI-0041 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 53 (Scan ID: 53)
#   Patient LIDC-IDRI-0042 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 54 (Scan ID: 54)
#   Patient LIDC-IDRI-0043 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 55 (Scan ID: 55)
#   Patient LIDC-IDRI-0044 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 56 (Scan ID: 56)
#   Patient LIDC-IDRI-0045 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 57 (Scan ID: 57)
#   Patient LIDC-IDRI-0046 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 58 (Scan ID: 58)
#
# Processing Patient 59 (Scan ID: 59)
#   Patient LIDC-IDRI-0048 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 60 (Scan ID: 60)
#   Patient LIDC-IDRI-0049 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 61 (Scan ID: 61)
#
# Processing Patient 62 (Scan ID: 62)
#   Patient LIDC-IDRI-0051 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 63 (Scan ID: 63)
#   Patient LIDC-IDRI-0052 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 64 (Scan ID: 64)
#   Patient LIDC-IDRI-0053 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 65 (Scan ID: 65)
#   Patient LIDC-IDRI-0054 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 66 (Scan ID: 66)
#   Patient LIDC-IDRI-0055 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 67 (Scan ID: 67)
#   Patient LIDC-IDRI-0056 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 68 (Scan ID: 68)
#
# Processing Patient 69 (Scan ID: 69)
#   Patient LIDC-IDRI-0058 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 70 (Scan ID: 70)
#
# Processing Patient 71 (Scan ID: 71)
#
# Processing Patient 72 (Scan ID: 72)
#   Patient LIDC-IDRI-0061 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 73 (Scan ID: 73)
#   No nodules annotated for this patient
#
# Processing Patient 74 (Scan ID: 74)
#   Patient LIDC-IDRI-0063 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 75 (Scan ID: 75)
#   Patient LIDC-IDRI-0064 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 76 (Scan ID: 76)
#
# Processing Patient 77 (Scan ID: 77)
#
# Processing Patient 78 (Scan ID: 78)
#   Patient LIDC-IDRI-0067 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 79 (Scan ID: 79)
#   Patient LIDC-IDRI-0068 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 80 (Scan ID: 80)
#   Patient LIDC-IDRI-0070 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 81 (Scan ID: 81)
#   No nodules annotated for this patient
#
# Processing Patient 82 (Scan ID: 82)
#
# Processing Patient 83 (Scan ID: 83)
#   Patient LIDC-IDRI-0073 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 84 (Scan ID: 84)
#   Patient LIDC-IDRI-0074 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 85 (Scan ID: 85)
#
# Processing Patient 86 (Scan ID: 86)
#   Patient LIDC-IDRI-0076 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 87 (Scan ID: 87)
#   Patient LIDC-IDRI-0077 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 88 (Scan ID: 88)
#   Patient LIDC-IDRI-0080 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 89 (Scan ID: 89)
#   Patient LIDC-IDRI-0081 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 90 (Scan ID: 90)
#
# Processing Patient 91 (Scan ID: 91)
#   Patient LIDC-IDRI-0083 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 92 (Scan ID: 92)
#   Patient LIDC-IDRI-0084 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 93 (Scan ID: 93)
#   Patient LIDC-IDRI-0085 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 94 (Scan ID: 94)
#   Patient LIDC-IDRI-0086 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 95 (Scan ID: 95)
#   Patient LIDC-IDRI-0087 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 96 (Scan ID: 96)
#   Patient LIDC-IDRI-0088 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 97 (Scan ID: 97)
#
# Processing Patient 98 (Scan ID: 98)
#   Patient LIDC-IDRI-0090 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 99 (Scan ID: 99)
#   Patient LIDC-IDRI-0091 has a benign nodule (malignancy score of 1 or 2).
#
# Processing Patient 100 (Scan ID: 100)
#   Patient LIDC-IDRI-0092 has a benign nodule (malignancy score of 1 or 2).
#
# Patients with benign nodules (malignancy score of 1 or 2):
# ['LIDC-IDRI-0078', 'LIDC-IDRI-0069', 'LIDC-IDRI-0079', 'LIDC-IDRI-0101', 'LIDC-IDRI-0110', 'LIDC-IDRI-0132', 'LIDC-IDRI-0136', 'LIDC-IDRI-0150', 'LIDC-IDRI-0151', 'LIDC-IDRI-0154', 'LIDC-IDRI-0003', 'LIDC-IDRI-0004', 'LIDC-IDRI-0005', 'LIDC-IDRI-0006', 'LIDC-IDRI-0008', 'LIDC-IDRI-0009', 'LIDC-IDRI-0010', 'LIDC-IDRI-0011', 'LIDC-IDRI-0012', 'LIDC-IDRI-0013', 'LIDC-IDRI-0014', 'LIDC-IDRI-0016', 'LIDC-IDRI-0017', 'LIDC-IDRI-0018', 'LIDC-IDRI-0019', 'LIDC-IDRI-0020', 'LIDC-IDRI-0021', 'LIDC-IDRI-0022', 'LIDC-IDRI-0024', 'LIDC-IDRI-0025', 'LIDC-IDRI-0026', 'LIDC-IDRI-0027', 'LIDC-IDRI-0030', 'LIDC-IDRI-0031', 'LIDC-IDRI-0033', 'LIDC-IDRI-0034', 'LIDC-IDRI-0039', 'LIDC-IDRI-0040', 'LIDC-IDRI-0041', 'LIDC-IDRI-0042', 'LIDC-IDRI-0043', 'LIDC-IDRI-0044', 'LIDC-IDRI-0045', 'LIDC-IDRI-0046', 'LIDC-IDRI-0048', 'LIDC-IDRI-0049', 'LIDC-IDRI-0051', 'LIDC-IDRI-0052', 'LIDC-IDRI-0053', 'LIDC-IDRI-0054', 'LIDC-IDRI-0055', 'LIDC-IDRI-0056', 'LIDC-IDRI-0058', 'LIDC-IDRI-0061', 'LIDC-IDRI-0063', 'LIDC-IDRI-0064', 'LIDC-IDRI-0067', 'LIDC-IDRI-0068', 'LIDC-IDRI-0070', 'LIDC-IDRI-0073', 'LIDC-IDRI-0074', 'LIDC-IDRI-0076', 'LIDC-IDRI-0077', 'LIDC-IDRI-0080', 'LIDC-IDRI-0081', 'LIDC-IDRI-0083', 'LIDC-IDRI-0084', 'LIDC-IDRI-0085', 'LIDC-IDRI-0086', 'LIDC-IDRI-0087', 'LIDC-IDRI-0088', 'LIDC-IDRI-0090', 'LIDC-IDRI-0091', 'LIDC-IDRI-0092']
